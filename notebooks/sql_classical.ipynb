# %% [markdown]
# # Shockley-Queisser Limit (SQL) of Solar Cells

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 10, 2)
y = np.exp(x)

# %%
plt.plot(x, y, 'r-')
plt.show()
